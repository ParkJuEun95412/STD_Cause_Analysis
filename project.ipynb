# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

pr=pd.read_csv('prep.csv')
pr
# Out:
#     year  smoke  stress  depress  drink  sex  contraception  Pre_puberty  \
# 0   2000    NaN     NaN      NaN    NaN  NaN           79.3          NaN
# 1   2001    NaN     NaN      NaN    NaN  NaN            NaN          NaN
# 2   2002    NaN     NaN      NaN    NaN  NaN            NaN          NaN
# 3   2003    NaN     NaN      NaN    NaN  NaN           84.5          NaN
# 4   2004    NaN     NaN      NaN    NaN  NaN            NaN          NaN
# 5   2005    NaN     NaN      NaN    NaN  NaN            NaN          NaN
# 6   2006   12.8    46.5     41.4   28.6  5.1           79.6          NaN
# 7   2007   13.3    46.5     41.3   27.8  5.2            NaN          NaN
# 8   2008   12.8    43.7     38.8   24.5  5.1            NaN          NaN
# 9   2009   12.8    43.2     37.5   21.1  5.1           80.0          NaN
# 10  2010   12.1    43.8     37.4   21.1  5.3            NaN     0.413820
# 11  2011   12.1    42.0     32.8   20.6  4.9            NaN     0.692249
# ...

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 15 columns):
# year             19 non-null int64
# smoke            13 non-null float64
# stress           13 non-null float64
# depress          13 non-null float64
# drink            13 non-null float64
# sex              13 non-null float64
# contraception    7 non-null float64
# Pre_puberty      9 non-null float64
# std              17 non-null float64
# gini             7 non-null float64
# single           14 non-null float64
# abortion         9 non-null float64
# obesity          13 non-null float64
# education        12 non-null float64
# internet         19 non-null float64
# dtypes: float64(14), int64(1)
# memory usage: 2.4 KB

# %%
pr.isnull().sum()
# Out:
# year              0
# smoke             6
# stress            6
# depress           6
# drink             6
# sex               6
# contraception    12
# Pre_puberty      10
# std               2
# gini             12
# single            5
# abortion         10
# obesity           6
# education         7
# internet          0
# dtype: int64

# %%
pr['contraception']=pr['contraception'].fillna(method='ffill')

# %%
pr
# Out:
#     year  smoke  stress  depress  drink  sex  contraception  Pre_puberty  \
# 0   2000    NaN     NaN      NaN    NaN  NaN           79.3          NaN
# 1   2001    NaN     NaN      NaN    NaN  NaN           79.3          NaN
# 2   2002    NaN     NaN      NaN    NaN  NaN           79.3          NaN
# 3   2003    NaN     NaN      NaN    NaN  NaN           84.5          NaN
# 4   2004    NaN     NaN      NaN    NaN  NaN           84.5          NaN
# 5   2005    NaN     NaN      NaN    NaN  NaN           84.5          NaN
# 6   2006   12.8    46.5     41.4   28.6  5.1           79.6          NaN
# 7   2007   13.3    46.5     41.3   27.8  5.2           79.6          NaN
# 8   2008   12.8    43.7     38.8   24.5  5.1           79.6          NaN
# 9   2009   12.8    43.2     37.5   21.1  5.1           80.0          NaN
# 10  2010   12.1    43.8     37.4   21.1  5.3           80.0     0.413820
# 11  2011   12.1    42.0     32.8   20.6  4.9           80.0     0.692249
# ...

# %%
df=pr.iloc[10:]
df
# Out:
#     year  smoke  stress  depress  drink  sex  contraception  Pre_puberty  \
# 10  2010   12.1    43.8     37.4   21.1  5.3           80.0     0.413820
# 11  2011   12.1    42.0     32.8   20.6  4.9           80.0     0.692249
# 12  2012   11.4    41.9     30.5   19.4  4.3           77.1     0.858238
# 13  2013    9.7    41.4     30.9   16.3  5.3           77.1     1.065779
# 14  2014    9.2    37.0     26.7   16.7  5.3           77.1     1.204761
# 15  2015    7.8    35.4     23.6   16.7  5.0           79.6     1.328386
# 16  2016    6.3    37.4     25.5   15.0  4.6           79.6     1.575468
# 17  2017    6.4    37.2     25.1   16.1  5.2           79.6     1.800836
# 18  2018    6.7    40.4     27.1   16.9  5.7           82.3     2.005124
#
#       std   gini  single  abortion  obesity  education  internet
# 10  0.005  0.310     9.2     148.0      5.3       73.6      77.8
# 11  0.006  0.311     9.3     143.0      5.6       71.7      78.0
# ...

# %%
corr=df.corr(method='pearson')
corr
# Out:
#                    year     smoke    stress   depress     drink       sex  \
# year           1.000000 -0.964495 -0.675335 -0.842998 -0.818247  0.303346
# smoke         -0.964495  1.000000  0.753079  0.857210  0.890184 -0.232843
# stress        -0.675335  0.753079  1.000000  0.929558  0.768578  0.012591
# depress       -0.842998  0.857210  0.929558  1.000000  0.842727  0.023728
# drink         -0.818247  0.890184  0.768578  0.842727  1.000000 -0.130107
# sex            0.303346 -0.232843  0.012591  0.023728 -0.130107  1.000000
# contraception  0.403595 -0.346123  0.026854 -0.058462  0.062358  0.420884
# Pre_puberty    0.996861 -0.949061 -0.637244 -0.823106 -0.808749  0.306831
# std            0.918957 -0.865670 -0.435656 -0.631357 -0.588041  0.324387
# gini          -0.771062  0.735675  0.833430  0.824342  0.752393 -0.160456
# single         0.947910 -0.954448 -0.816537 -0.933853 -0.917445  0.190718
# abortion      -0.989098  0.964100  0.705869  0.841492  0.783918 -0.291056
# ...
