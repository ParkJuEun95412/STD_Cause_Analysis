# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.max_columns', None)
pr=pd.read_csv('prep.csv')
pr
# Out:
#     year  std_total  std_exp  hiv  smoke  drink  stress  depress  \
# 0   2000        NaN      NaN    2    NaN    NaN     NaN      NaN
# 1   2001        NaN      NaN    6    NaN    NaN     NaN      NaN
# 2   2002      0.028      NaN    5    NaN    NaN     NaN      NaN
# 3   2003      0.021      NaN    6    NaN    NaN     NaN      NaN
# 4   2004      0.014      NaN   12    NaN    NaN     NaN      NaN
# 5   2005      0.009      NaN   16    NaN    NaN     NaN      NaN
# 6   2006      0.006     0.13   13   12.8   28.6    46.5     41.4
# 7   2007      0.006     0.12   17   13.3   27.8    46.5     41.3
# 8   2008      0.006     0.11   20   12.8   24.5    43.7     38.8
# 9   2009      0.005     0.10   27   12.8   21.1    43.2     37.5
# 10  2010      0.005     0.09   28   12.1   21.1    43.8     37.4
# 11  2011      0.006     0.11   40   12.1   20.6    42.0     32.8
# 12  2012      0.006     0.13   32   11.4   19.4    41.9     30.5
# ...

# %%
# KNN으로 결측치 처리하기 ####################################################### 무시
welfac = pr['welfare_fac']
welfac = pd.DataFrame(welfac)

# import knnimpute
from missingpy import KNNImputer
imputer = KNNImputer(n_neighbors=2)
welfac_new = imputer.fit_transform(welfac)
welfac_new

###################################################################### KNN 결측치 채우기 연습 - 무시
import numpy as np
from missingpy import KNNImputer
nan = np.nan
X = [[1, 2, nan], [3, 4, 3], [nan, 6, 5], [8, 8, 7]]
imputer = KNNImputer(n_neighbors=2, weights="uniform")
imputer.fit_transform(X)

###################################################################### 사이킷런 버전 확인하는 법 - 무시
import nltk
import sklearn
# pip freeze | grep scikit-learn
print('The nltk version is {}.'.format(nltk.__version__))
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# C:\Users\ICT01_04\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\ICT01_04\Anaconda3\lib\site-packages\missingpy\knnimpute.py:224: UserWarning: There are rows with more than 50.0% missing values. These rows are not included as donor neighbors.
#   .format(self.row_max_missing * 100))
# C:\Users\ICT01_04\Anaconda3\lib\site-packages\missingpy\knnimpute.py:282: UserWarning: There are rows with more than 50.0% missing values. The missing features in these rows are imputed with column means.
#   .format(self.row_max_missing * 100))
# ...

# %%
df=pr.iloc[9:]
ds = df.copy()
df = ds
df
# Out:
#     year  std_total  std_exp  hiv  smoke  drink  stress  depress  \
# 9   2009      0.005     0.10   27   12.8   21.1    43.2     37.5
# 10  2010      0.005     0.09   28   12.1   21.1    43.8     37.4
# 11  2011      0.006     0.11   40   12.1   20.6    42.0     32.8
# 12  2012      0.006     0.13   32   11.4   19.4    41.9     30.5
# 13  2013      0.006     0.11   53    9.7   16.3    41.4     30.9
# 14  2014      0.007     0.13   40    9.2   16.7    37.0     26.7
# 15  2015      0.013     0.26   42    7.8   16.7    35.4     23.6
# 16  2016      0.018     0.39   36    6.3   15.0    37.4     25.5
# 17  2017      0.018     0.35   34    6.4   16.1    37.2     25.1
# 18  2018      0.026     0.46   19    6.7   16.9    40.4     27.1
#
#     sex_frequency  contraception  abortion  obesity  teen_crime  tuberculosis  \
# 9             5.1           80.0       NaN      5.1       17.33        2421.0
# 10            5.3            NaN     148.0      5.3       13.90        2338.0
# ...

# %%
# 결측치 시각화
import missingno as msno
msno.bar(df)

# %%
# 결측치 시각화
msno.heatmap(df)
# Out:
# C:\Users\ICT01_04\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ICT01_04\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df['contraception']=df['contraception'].fillna(method='ffill')
df['welfare_fac']=df['welfare_fac'].fillna(method='ffill')
df['sports_fac']=df['sports_fac'].fillna(method='ffill')
df['abortion']=df['abortion'].fillna(method='ffill')
df['pre_puberty']=df['pre_puberty'].fillna(method='ffill')

# %%
df=df.fillna(df.mean())
df
# Out:
#     year  std_total  std_exp  hiv  smoke  drink  stress  depress  \
# 9   2009      0.005     0.10   27   12.8   21.1    43.2     37.5
# 10  2010      0.005     0.09   28   12.1   21.1    43.8     37.4
# 11  2011      0.006     0.11   40   12.1   20.6    42.0     32.8
# 12  2012      0.006     0.13   32   11.4   19.4    41.9     30.5
# 13  2013      0.006     0.11   53    9.7   16.3    41.4     30.9
# 14  2014      0.007     0.13   40    9.2   16.7    37.0     26.7
# 15  2015      0.013     0.26   42    7.8   16.7    35.4     23.6
# 16  2016      0.018     0.39   36    6.3   15.0    37.4     25.5
# 17  2017      0.018     0.35   34    6.4   16.1    37.2     25.1
# 18  2018      0.026     0.46   19    6.7   16.9    40.4     27.1
#
#     sex_frequency  contraception    abortion  obesity  teen_crime  \
# 9             5.1           80.0   99.333333      5.1       17.33
# 10            5.3           80.0  148.000000      5.3       13.90
# ...

# %%
import missingno as msno
msno.bar(df)

# %%
df.isnull().sum()
# Out:
# year                                   0
# std_total                              0
# std_exp                                0
# hiv                                    0
# smoke                                  0
# drink                                  0
# stress                                 0
# depress                                0
# sex_frequency                          0
# contraception                          0
# abortion                               0
# obesity                                0
# teen_crime                             0
# tuberculosis                           0
# pre_puberty                            0
# single                                 0
# private_edu                            0
# exercise3_week                         0
# basic_livelihood_security_recipient    0
# culture_fac                            0
# welfare_fac                            0
# sports_fac                             0
# park                                   0
# ...

# %%
###################################################################### 상관성 분석
corr=df.corr(method='pearson')
corr
# Out:
#                                          year  std_total   std_exp       hiv  \
# year                                 1.000000   0.900230  0.900916 -0.064110
# std_total                            0.900230   1.000000  0.989013 -0.408142
# std_exp                              0.900916   0.989013  1.000000 -0.365968
# hiv                                 -0.064110  -0.408142 -0.365968  1.000000
# smoke                               -0.970646  -0.867905 -0.894358 -0.010824
# drink                               -0.861829  -0.631646 -0.672601 -0.343173
# stress                              -0.731934  -0.495052 -0.548646 -0.301736
# depress                             -0.887595  -0.662545 -0.699605 -0.229669
# sex_frequency                        0.244750   0.303176  0.187652 -0.185626
# contraception                        0.256479   0.617948  0.570995 -0.680483
# abortion                            -0.843505  -0.886213 -0.893269  0.328025
# ...

# %%
from sklearn.datasets import make_classification
X, y = make_classification(1000)

from sklearn.ensemble import RandomForestClassifier
rf =RandomForestClassifier() # n_estimators=30이면 다름. 디폴트는 10
rf.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print("Accuracy:\t", (y== rf.predict(X)).mean()) # 같으면 1, 거짓이면 0. 랜덤이라 매번 값 다름
# Out:
# Accuracy:	 1.0

# %%
f, ax = plt.subplots(figsize=(7,5))
ax.bar(range(0, len(rf.feature_importances_)),
      rf.feature_importances_)
ax.set_title("특성중요도")
# Out:
# Text(0.5, 1.0, '특성중요도')

# %%
print("특성수", rf.n_features_)
print("모델", rf.estimators_)
# Out:
# 특성수 20
# 모델 [DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=510437544, splitter='best'), DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=716045891, splitter='best'), DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
# ...

# %%
#################################### 영택이네 코드

from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(x)

randomF= RandomForestRegressor(n_estimators=100,max_depth =3,min_samples_leaf=1).fit(scaled_data,y)

print('정확도:%.2f'%(randomF.score(scaled_data,y)*100),"%")

# z점수
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import scale, robust_scale, minmax_scale , maxabs_scale
scaler = scale(x)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print("Logi.Regre Z점수 정확도:%.2f" %(logreg.score(scaler,y)*100),"%")
#
scaler = maxabs_scale(x)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print('Logi.Regre maxabs점수 정확도:%.2f'%(logreg.score(scaler,y)*100),"%")
#
scaler = minmax_scale(x)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print('Logi.Regre minmax점수 정확도:%.2f'%(logreg.score(scaler,y)*100),"%")
#
scaler = robust_scale(x)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print('Logi.Regre robust점수 정확도:%.2f'%(logreg.score(scaler,y)*100),"%")


# Random forest scale
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.preprocessing import scale, robust_scale, minmax_scale , maxabs_scale
scaler = scale(x)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ Z_점수 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
scaler = robust_scale(x)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ robust 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
scaler = minmax_scale(x)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ minmax 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
scaler = maxabs_scale(x)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ maxabs 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a36a1b4e3ef9> in <module>
#       5
#       6 scaler = MinMaxScaler(feature_range=(0,1))
# ----> 7 scaled_data = scaler.fit_transform(x)
#       8
#       9 randomF= RandomForestRegressor(n_estimators=100,max_depth =3,min_samples_leaf=1).fit(scaled_data,y)
#
# NameError: name 'x' is not defined

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 9 to 18
# Data columns (total 37 columns):
# year                                   10 non-null int64
# std_total                              10 non-null float64
# std_exp                                10 non-null float64
# hiv                                    10 non-null int64
# smoke                                  10 non-null float64
# drink                                  10 non-null float64
# stress                                 10 non-null float64
# depress                                10 non-null float64
# sex_frequency                          10 non-null float64
# contraception                          10 non-null float64
# abortion                               10 non-null float64
# obesity                                10 non-null float64
# teen_crime                             10 non-null float64
# tuberculosis                           10 non-null float64
# ...

# %%
output = df
output
# Out:
#     year  std_total  std_exp  hiv  smoke  drink  stress  depress  \
# 9   2009      0.005     0.10   27   12.8   21.1    43.2     37.5
# 10  2010      0.005     0.09   28   12.1   21.1    43.8     37.4
# 11  2011      0.006     0.11   40   12.1   20.6    42.0     32.8
# 12  2012      0.006     0.13   32   11.4   19.4    41.9     30.5
# 13  2013      0.006     0.11   53    9.7   16.3    41.4     30.9
# 14  2014      0.007     0.13   40    9.2   16.7    37.0     26.7
# 15  2015      0.013     0.26   42    7.8   16.7    35.4     23.6
# 16  2016      0.018     0.39   36    6.3   15.0    37.4     25.5
# 17  2017      0.018     0.35   34    6.4   16.1    37.2     25.1
# 18  2018      0.026     0.46   19    6.7   16.9    40.4     27.1
#
#     sex_frequency  contraception    abortion  obesity  teen_crime  \
# 9             5.1           80.0   99.333333      5.1       17.33
# 10            5.3           80.0  148.000000      5.3       13.90
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
fitted = min_max_scaler.fit(output)
print(fitted.data_max_)
output = min_max_scaler.transform(output)
output = pd.DataFrame(output, columns=df.columns, index=list(df.index.values))
print(output.head())
# Out:
# [2.01800000e+03 2.60000000e-02 4.60000000e-01 5.30000000e+01
#  1.28000000e+01 2.11000000e+01 4.38000000e+01 3.75000000e+01
#  5.70000000e+00 8.23000000e+01 1.48000000e+02 1.08000000e+01
#  1.73300000e+01 2.42100000e+03 2.00512438e+00 1.09000000e+01
#  7.50000000e+01 3.79000000e+01 1.74369000e+06 5.45000000e+00
#  1.44000000e+01 1.13720000e+02 1.01000000e+01 2.88000000e+00
#  9.15000000e+01 1.68000000e+00 7.00000000e-02 1.26200000e+02
#  1.77000000e+01 3.15000000e+01 1.36000000e+01 9.00000000e+00
#  1.89000000e+01 3.33460000e+04 1.04450000e+02 3.14000000e-01
#  1.00329960e+07]
#         year  std_total   std_exp       hiv     smoke     drink    stress  \
# 9   0.000000   0.000000  0.027027  0.235294  1.000000  1.000000  0.928571
# 10  0.111111   0.000000  0.000000  0.264706  0.892308  1.000000  1.000000
# 11  0.222222   0.047619  0.054054  0.617647  0.892308  0.918033  0.785714
# 12  0.333333   0.047619  0.108108  0.382353  0.784615  0.721311  0.773810
# ...

# %%
############################## min-max 정규화 완료
output
# Out:
#         year  std_total   std_exp       hiv     smoke     drink    stress  \
# 9   0.000000   0.000000  0.027027  0.235294  1.000000  1.000000  0.928571
# 10  0.111111   0.000000  0.000000  0.264706  0.892308  1.000000  1.000000
# 11  0.222222   0.047619  0.054054  0.617647  0.892308  0.918033  0.785714
# 12  0.333333   0.047619  0.108108  0.382353  0.784615  0.721311  0.773810
# 13  0.444444   0.047619  0.054054  1.000000  0.523077  0.213115  0.714286
# 14  0.555556   0.095238  0.108108  0.617647  0.446154  0.278689  0.190476
# 15  0.666667   0.380952  0.459459  0.676471  0.230769  0.278689  0.000000
# 16  0.777778   0.619048  0.810811  0.500000  0.000000  0.000000  0.238095
# 17  0.888889   0.619048  0.702703  0.441176  0.015385  0.180328  0.214286
# 18  1.000000   1.000000  1.000000  0.000000  0.061538  0.311475  0.595238
#
#      depress  sex_frequency  contraception  abortion   obesity  teen_crime  \
# 9   1.000000       0.571429       0.557692  0.527508  0.000000    1.000000
# ...

# %%
# min-max 시각화
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
min_max_scaler.fit(X)
x_scaled = min_max_scaler.fit_transform(X)
# df = pd.DataFrame(x_scaled, columns = X.columns)
output.hist( figsize = (20 , 15))
plt.show()

# %%
# standardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(output)
x_scaled = scaler.fit_transform(X)
df = pd.DataFrame(x_scaled, columns = X.colu
                  
                  
                  
                  mns)
df.hist( figsize = (20 , 15))
plt.show()
# Out:
#   File "<ipython-input-283-42080146cae1>", line 10
#     mns)
#       ^
# SyntaxError: invalid syntax

# %%
output_ext = output[['std_total','std_exp', 'contraception', 'abortion','obesity','tuberculosis','pre_puberty',
                      'park','internet','per_capita_income','cosmetic']]
output_ext
# Out:
#     std_total   std_exp  contraception  abortion   obesity  tuberculosis  \
# 9    0.000000  0.027027       0.557692  0.527508  0.000000      1.000000
# 10   0.000000  0.000000       0.557692  1.000000  0.035088      0.957370
# 11   0.047619  0.054054       0.557692  0.951456  0.087719      0.955829
# 12   0.047619  0.108108       0.000000  0.815534  0.192982      0.695942
# 13   0.047619  0.054054       0.000000  0.786408  0.263158      0.494093
# 14   0.095238  0.108108       0.000000  0.485437  0.315789      0.396507
# 15   0.380952  0.459459       0.480769  0.368932  0.421053      0.343092
# 16   0.619048  0.810811       0.480769  0.223301  0.701754      0.194145
# 17   0.619048  0.702703       0.480769  0.116505  0.859649      0.114535
# 18   1.000000  1.000000       1.000000  0.000000  1.000000      0.000000
#
#     pre_puberty  park  internet  per_capita_income  cosmetic
# 9      0.504148  0.00  0.000000           0.000000  0.000000
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(output_ext, diag_kind='hist')
plt.show()

# %%
df_final = df[['std_total','std_exp', 'contraception', 'abortion','obesity','tuberculosis','pre_puberty',
               'park','internet','per_capita_income','cosmetic']]
df_final

#https://teddylee777.github.io/machine-learning/sklearn%EC%99%80-pandas%EB%A5%BC-%ED%99%9C%EC%9A%A9%ED%95%9C-%EA%B0%84%EB%8B%A8-%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D
# Out:
#     std_total  std_exp  contraception    abortion  obesity  tuberculosis  \
# 9       0.005     0.10           80.0   99.333333      5.1        2421.0
# 10      0.005     0.09           80.0  148.000000      5.3        2338.0
# 11      0.006     0.11           80.0  143.000000      5.6        2335.0
# 12      0.006     0.13           77.1  129.000000      6.2        1829.0
# 13      0.006     0.11           77.1  126.000000      6.6        1436.0
# 14      0.007     0.13           77.1   95.000000      6.9        1246.0
# 15      0.013     0.26           79.6   83.000000      7.5        1142.0
# 16      0.018     0.39           79.6   68.000000      9.1         852.0
# 17      0.018     0.35           79.6   57.000000     10.0         697.0
# 18      0.026     0.46           82.3   45.000000     10.8         474.0
#
#     pre_puberty  park  internet  per_capita_income    cosmetic
# 9      1.216074   8.1      77.2              19152   5534176.0
# ...

# %%
cmap = sns.light_palette("darkgray", as_cmap=True)
sns.heatmap(df_final.corr(), annot=True, cmap=cmap)
plt.show()
# Out:
# C:\Users\ICT01_04\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ICT01_04\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
cmap = sns.light_palette("skyblue", as_cmap=True)
sns.heatmap(output.corr(), annot=True, cmap=cmap)
# plt.figure(figsize = (40,40))
plt.show()

plt.savefig('img.png', dpi = 800)

# %%
fig, ax = plt.subplots( figsize=(50,50) )


mask = np.zeros_like(output.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# 히트맵을 그린다
sns.heatmap(output.corr(), 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()

# %%
#### std_total

from sklearn.model_selection import train_test_split
from statsmodels.datasets.longley import load_pandas
import statsmodels.api as sm

def get_model1(seed):
    df_train, df_test = train_test_split(df_final, test_size=0.5, random_state=seed)
    model = sm.OLS.from_formula("std_total ~ contraception+abortion+obesity+tuberculosis+pre_puberty+park+internet+per_capita_income+cosmetic", data=df_train)
    return df_train, df_test, model.fit()

df_train, df_test, result1 = get_model1(3)
print(result1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              std_total   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                     0.000
# Date:                Wed, 22 Jan 2020   Prob (F-statistic):                nan
# Time:                        20:51:30   Log-Likelihood:                 154.56
# No. Observations:                   5   AIC:                            -299.1
# Df Residuals:                       0   BIC:                            -301.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          5.132e-06        inf          0        nan         nan         nan
# ...

# %%
#### std_exp 

def get_model1(seed):
    df_train, df_test = train_test_split(df_final, test_size=0.5, random_state=seed)
    model = sm.OLS.from_formula("std_exp ~ contraception+abortion+obesity+tuberculosis+pre_puberty+park+internet+per_capita_income+cosmetic", data=df_train)
    return df_train, df_test, model.fit()

df_train, df_test, result1 = get_model1(3)
print(result1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                std_exp   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                     0.000
# Date:                Wed, 22 Jan 2020   Prob (F-statistic):                nan
# Time:                        10:51:17   Log-Likelihood:                 122.20
# No. Observations:                   4   AIC:                            -236.4
# Df Residuals:                       0   BIC:                            -238.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept         -7.915e-06        inf         -0        nan         nan         nan
# ...

# %%
X = output_ext.iloc[:,2:]
y = output_ext.iloc[:,1] # y = std_exp
X,y
# Out:
# (    contraception  abortion   obesity  tuberculosis  pre_puberty  park  \
#  9        0.557692  0.527508  0.000000      1.000000     0.504148  0.00
#  10       0.557692  1.000000  0.035088      0.957370     0.000000  0.15
#  11       0.557692  0.951456  0.087719      0.955829     0.174969  0.10
#  12       0.000000  0.815534  0.192982      0.695942     0.279279  0.40
#  13       0.000000  0.786408  0.263158      0.494093     0.409701  0.25
#  14       0.000000  0.485437  0.315789      0.396507     0.497040  0.25
#  15       0.480769  0.368932  0.421053      0.343092     0.574727  0.35
#  16       0.480769  0.223301  0.701754      0.194145     0.729997  0.55
#  17       0.480769  0.116505  0.859649      0.114535     0.871622  0.75
#  18       1.000000  0.000000  1.000000      0.000000     1.000000  1.00
#
#      internet  per_capita_income  cosmetic
#  9   0.000000           0.000000  0.000000
#  10  0.041958           0.276948  0.172084
#  11  0.055944           0.419050  0.234639
# ...

# %%
# from sklearn.ensemble import RandomForestRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn import utils

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

rf = RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=0)
rf.fit(X_train, y_train)
rf

k_fold = KFold(n_splits=2, shuffle=True, random_state=0)
score = cross_val_score(rf, X_train, y_train, cv=k_fold, scoring=None)
print(score)
score = score.mean()
print(score)
# 0에 근접할수록 좋은 데이터
print("Score= {0:.5f}".format(score))
print(rf)
# Out:
# [0.64703573 0.646623  ]
# 0.6468293685752384
# Score= 0.64683
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
param_grid = [
    {'n_estimators': [3,10,30], 'max_features': [2,4,6,8]},
    {'bootstrap': [False], 'n_estimators': [3,10], 'max_features':[2,3,4]},
]

forest_reg = RandomForestRegressor()

grid_search = GridSearchCV(forest_reg, param_grid, cv=5, return_train_score=True)



grid_search.fit(X_train, y_train)

# %%
grid_search.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-135bd00187f2> in <module>
# ----> 1 grid_search.score(X_test, y_test)
#
# NameError: name 'grid_search' is not defined

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pc = pca.fit_transform(output_ext)

# %%
import matplotlib.pyplot as plt
plt.scatter(pc[:,0],pc[:,1])
# Out:
# C:\Users\ICT01_04\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ICT01_04\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
S = output_ext

plt.plot(S.T, 'o:')
plt.xticks()
plt.title("성병")
plt.legend(["표본 {}".format(i + 1) for i in range(9)])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
# pd.set_option('display.max_columns', None)
std=pd.read_csv('std1519.csv')
std
# Out:
#       연도    임질  클라미디아감염증  성기단순포진  첨규콘딜롬
# 0   2002  1668       172      11      9
# 1   2003  1136       231      11     19
# 2   2004   670       210       7     16
# 3   2005   399       185      18     11
# 4   2006   281       118      12     20
# 5   2007   252       120      19     23
# 6   2008   213       116      18     29
# 7   2009   158       131      18     38
# 8   2010   136       100      30     43
# 9   2011   161       142      18     45
# 10  2012   126       145      17     68
# 11  2013   111       165      30     55
# 12  2014   118       186      41     74
# 13  2015   208       342      69    116
# 14  2016   271       473     105    122
# 15  2017   187       564      85    135
# 16  2018   229       772     171    187
# 17  2019   299       889     186    167

# %%
# sns.lineplot(x = std.iloc[:, 0], y=std.iloc[:, 1:], data=std)
sb.pointplot(x = '연도', y= '임질',data=std)

# %matplotlib inline
fig, ax = plt.subplots()
sb.set(rc={'axes.facecolor':'cornflowerblue', 'figure.facecolor':'cornflowerblue'})
#sb.pointplot(x='연도', y='임질', data=std, ax=ax,  color='navy')
sb.pointplot(x='연도', y='클라미디아감염증', data=std, ax=ax, color='hotpink')
sb.pointplot(x='연도', y='성기단순포진', data=std, ax=ax, color='red')
sb.pointplot(x='연도', y='첨규콘딜롬', data=std, ax=ax, color='yellow')
labels = ax.get_xticklabels() 
ax.set_xticklabels(labels, rotation=-30)

plt.show()

# %%
std=std.iloc[:,1:]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname='c:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family = font_name)

ax = sns.lineplot(data=std)
ax.set_ylabel("성병 신고수")
ax.set_xlabel("연도")

plt.show()

# %%
# standardScaler 표준화
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
x_scaled = scaler.fit_transform(X)
# df = pd.DataFrame(x_scaled, columns = X.columns)
output_ext.hist( figsize = (20 , 15))
plt.show()
